# %%
import os
import torch
import sys
import numpy as np
import matplotlib.pyplot as plt
from gsplat import rasterization
from optical.surface_2 import WaterSurface
from optical.surface_2 import TransformWaterSurface
from optical.utils.test_utils import LoadDataset
from optical.utils.test_utils import combert_into_colormap, compare_rasterization_variants, np_rgb_render

# %matplotlib inline
plt.rcParams['figure.figsize'] = (15.0, 12.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
# for auto-reloading extenrnal modules
# %load_ext autoreload
# %autoreload 2

device = torch.device("cuda:0")
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
# Dataset = LoadDataset()
Dataset = LoadDataset(
    w_ref_dataset_path=os.path.abspath(os.path.join(os.path.expanduser("~"), "dataset", "river4", "refraction")),
    wo_ref_dataset_path=os.path.abspath(os.path.join(os.path.expanduser("~"), "dataset", "river4", "gt")),
    wo_ref_model_path="../../results/favo/simple-river_MCMC_wo-refraction/ply/point_cloud_29999.ply")
Dataset.set_iamge(80)

means, scales, quats, opacities, colors = Dataset.get_model_param()
pixels_wo, pixels_w, camtoworld, worldtocam, cam_center, K, height, width, image_id = Dataset.get_camera_param()

# Setting Refraction Parameters
n = 1.33
plane = 0.0
num_newton_iters = 10
newton_atol = 1e-6
# Out:
# Loading 3D point cloud from: /home/taiki/dataset/river4/gt/points3d.ply
# [Parser] Loaded 81 images from /home/taiki/dataset/river4/gt.
# Loading 3D point cloud from: /home/taiki/dataset/river4/refraction/points3d.ply
# [Parser] Loaded 81 images from /home/taiki/dataset/river4/refraction.

# %%
t_m, t_q, t_s = TransformWaterSurface.apply(
    means, quats, scales, worldtocam,
    1.33, 0.0, True, True, "newton", 10, 1e-6, 1e-4, 
    True, "dPa_dP", "edges", 0.33, "real"
)
# Out:
# /home/taiki/try-papers/gsplat/optical/surface_2.py:163: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.n = torch.tensor(n, dtype=torch.float32, device=device, requires_grad=False)
# /home/taiki/try-papers/gsplat/optical/surface_2.py:164: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.plane = torch.tensor(plane, dtype=torch.float32, device=device, requires_grad=False)

# %%
WS = WaterSurface(
    means=means,
    quats=quats,
    scales=scales,
    cam_center=cam_center,
    n=n,
    plane=plane,
)

t_means = WS.transform_means()
# dPa_dP = WS.calc_dPa_dP()
dPa_dP = WS.calc_dPa_dP_with_minibatches()
t_quats = WS.transform_quats()

t_scales_edges_dev3 = WS.transform_scales(
    method_transform_scales="edges",
    coeff_transform_scales=1/3,
    scale_correct_space="real"
)

# %%
# opacities = torch.sigmoid(opacities)
# colors = torch.sigmoid(colors)
# colors = torch.logit(colors + 1e-6)  # Avoid log(0) by adding a small constant

render2, _, _ = rasterization(
    t_means,
    t_quats,
    t_scales_edges_dev3,
    opacities,
    colors,
    worldtocam,
    K,
    width,
    height,
    sh_degree=0,
    rasterize_mode="antialiased"
)
render2_clamped = torch.clamp(render2, 0.0, 1.0)
render2_np = render2_clamped.squeeze(0).detach().cpu().numpy()
render2_np_uint8 = (render2_np * 255).astype(np.uint8)
plt.imshow(render2_np_uint8)
plt.axis("off")
plt.show()

# %%
scale_correction_factor = WS.scale_correction_factor

# show histogram of scale_correction_factor
plt.hist(scale_correction_factor.cpu().detach().numpy(), bins=50)
plt.title("Scale Correction Factor Histogram")
plt.xlabel("Scale Correction Factor")
plt.ylabel("Frequency")
plt.show()

# %%
# show colors
colors_np = colors.squeeze().detach().cpu().numpy()

# show histogram of colors
plt.hist(colors_np, bins=50)
plt.title("Colors Histogram")
plt.xlabel("Colors")
plt.ylabel("Frequency")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 5
#       2 colors_np = colors.squeeze().detach().cpu().numpy()
#       4 # show histogram of colors
# ----> 5 plt.hist(colors_np, bins=50)
#       6 plt.title("Colors Histogram")
#       7 plt.xlabel("Colors")
#
# File ~/try-papers/gsplat/venv/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/try-papers/gsplat/venv/lib/python3.10/site-packages/matplotlib/pyplot.py:3467, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3442 @_copy_docstring_and_deprecators(Axes.hist)
#    3443 def hist(
#    3444     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3465     BarContainer | Polygon | list[BarContainer | Polygon],
#    3466 ]:
# -> 3467     return gca().hist(
#    3468         x,
#    3469         bins=bins,
#    3470         range=range,
#    3471         density=density,
#    3472         weights=weights,
#    3473         cumulative=cumulative,
#    3474         bottom=bottom,
#    3475         histtype=histtype,
#    3476         align=align,
#    3477         orientation=orientation,
#    3478         rwidth=rwidth,
#    3479         log=log,
#    3480         color=color,
#    3481         label=label,
#    3482         stacked=stacked,
#    3483         **({"data": data} if data is not None else {}),
#    3484         **kwargs,
#    3485     )
#
# File ~/try-papers/gsplat/venv/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/try-papers/gsplat/venv/lib/python3.10/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~/try-papers/gsplat/venv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:7037, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7034     stacked = True
#    7036 # Massage 'x' for processing.
# -> 7037 x = cbook._reshape_2D(x, 'x')
#    7038 nx = len(x)  # number of datasets
#    7040 # Process unit information.  _process_unit_info sets the unit and
#    7041 # converts the first dataset; then we convert each following dataset
#    7042 # one at a time.
#
# File ~/try-papers/gsplat/venv/lib/python3.10/site-packages/matplotlib/cbook.py:1401, in _reshape_2D(X, name)
#    1399         return [np.reshape(x, -1) for x in X]
#    1400     else:
# -> 1401         raise ValueError(f'{name} must have 2 or fewer dimensions')
#    1403 # Iterate over list of iterables.
#    1404 if len(X) == 0:
#
# ValueError: x must have 2 or fewer dimensions
