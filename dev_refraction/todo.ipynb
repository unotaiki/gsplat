# %% [markdown]
# # TODO
#
# - [後] Refraction時にGaussianを回転させる
# - [ ] Try Gaussian Splatting Training with Refraction
# - [ ] Try caemra optimization
# - [ ] より詳細なデータセットの作成
# - [x] ドローンの経路に加え、一点を円を描くように撮影した画像の取得
# - [ ] Surfaceに関する正則化
# - [ ] Surfelの形状にGaussianを制限
